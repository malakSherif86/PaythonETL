# %%
import pandas as pd
oi = pd.read_csv('/home/malak/staging_2/products/products.csv')
products= pd.read_csv('/home/malak/staging_2/order_items/order_items.csv')

# %%
products
# Out:
#       Unnamed: 0  order_id  item_id  product_id  quantity  list_price  \
# 0              0         1        1          20         1      599.99
# 1              1         2        1          20         1      599.99
# 2              2         3        1           3         1      999.99
# 3              3         4        1           2         2      749.99
# 4              4         5        1          10         2     1549.00
# ...          ...       ...      ...         ...       ...         ...
# 1574        1574      1611        1         191         1     2799.99
# 1575        1575      1612        1         242         1      699.99
# 1576        1576      1613        1         153         1     4999.99
# 1577        1577      1614        1         124         1     1499.00
# 1578        1578      1615        1         197         2     2299.99
#
#       discount                extract_time            source_name  USD_to_EGP  \
# ...

# %%
orders = pd.read_csv('/home/malak/staging_2/orders/orders.csv')
orders
# Out:
#       order_id  customer_id  order_date required_date shipped_date  store_id  \
# 0            1          259  2016-01-01    2016-01-03   2016-01-03         1
# 1            2         1212  2016-01-01    2016-01-04   2016-01-03         2
# 2            3          523  2016-01-02    2016-01-05   2016-01-03         2
# 3            4          175  2016-01-03    2016-01-04   2016-01-05         1
# 4            5         1324  2016-01-03    2016-01-06   2016-01-06         2
# ...        ...          ...         ...           ...          ...       ...
# 1610      1611            6  2018-09-06    2018-09-06   2018-04-02         2
# 1611      1612            3  2018-10-21    2018-10-21   2018-04-02         1
# 1612      1613            1  2018-11-18    2018-11-18   2018-04-02         2
# 1613      1614          135  2018-11-28    2018-11-28   2018-04-02         3
# 1614      1615          136  2018-12-28    2018-12-28   2018-04-02         3
#
# ...

# %%
orders_products = pd.merge(orders, products, on='order_id', how='inner')

# %%
allDF = pd.merge(orders_products, oi, on='product_id', how='inner')

# %%
allDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1579 entries, 0 to 1578
# Data columns (total 30 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        1579 non-null   int64
#  1   customer_id     1579 non-null   int64
#  2   order_date      1579 non-null   object
#  3   required_date   1579 non-null   object
#  4   shipped_date    1579 non-null   object
#  5   store_id        1579 non-null   int64
#  6   staff_id        1579 non-null   int64
#  7   extract_time_x  1579 non-null   object
#  8   source_name_x   1579 non-null   object
#  9   late_delivery   1579 non-null   bool
#  10  latency_days    469 non-null    float64
#  11  weekend         1579 non-null   bool
#  12  orderStatus     1579 non-null   object
#  13  Unnamed: 0      1579 non-null   int64
#  14  item_id         1579 non-null   int64
#  15  product_id      1579 non-null   int64
#  16  quantity        1579 non-null   int64
# ...

# %%
 allDF.to_csv('/home/malak/MODLING/information_mart/orders_products_details.csv')
