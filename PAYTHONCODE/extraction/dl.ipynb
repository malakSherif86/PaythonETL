# %%
import pandas as pd
brands = pd.read_csv('/home/malak/bikestore_dim/brands/brands.csv', header=0)

# %%
customers
# Out:
#       customer_id  first_name last_name           phone  \
# 0               1       Debra     Burks             NaN
# 1               2       Kasha      Todd             NaN
# 2               3      Tameka    Fisher             NaN
# 3               4       Daryl    Spence             NaN
# 4               5  Charolette      Rice  (916) 381-6003
# ...           ...         ...       ...             ...
# 1440         1441      Jamaal  Morrison             NaN
# 1441         1442      Cassie     Cline             NaN
# 1442         1443      Lezlie      Lamb             NaN
# 1443         1444      Ivette     Estes             NaN
# 1444         1445       Ester   Acevedo             NaN
#
#                         email                  street           city state  \
# 0       debra.burks@yahoo.com       9273 Thorne Ave.    Orchard Park    NY
# 1        kasha.todd@yahoo.com        910 Vine Street        Campbell    CA
# ...

# %%
import pandas as pd
staff= pd.read_csv('/home/malak/bikestore_dim/staff/staffs.csv', header=0)

# %%
import pandas as pd
categories= pd.read_csv('/home/malak/bikestore_dim/categories/categories.csv', header=0)

# %%
import pandas as pd
products= pd.read_csv('/home/malak/bikestore_dim/products/products.csv', header=0)

# %%
import pandas as pd
stocks= pd.read_csv('/home/malak/bikestore_dim/stocks/stocks.csv', header=0)

# %%
import pandas as pd
stores= pd.read_csv('/home/malak/bikestore_dim/stores/stores.csv', header=0)

# %%
import pandas as pd
customers= pd.read_csv('/home/malak/bikestore_dim/customers/customers.csv', header=0)

# %%
stores
# Out:
#    store_id        store_name           phone               email  \
# 0         1  Santa Cruz Bikes  (831) 476-4321                 NaN
# 1         2     Baldwin Bikes  (516) 379-8888  baldwin@bikes.shop
# 2         3     Rowlett Bikes  (972) 530-5555  rowlett@bikes.shop
#
#                 street        city state  zip_code
# 0   3700 Portola Drive  Santa Cruz    CA       NaN
# 1   4200 Chestnut Lane     Baldwin    NY   11432.0
# 2  8000 Fairway Avenue     Rowlett    TX   75088.0

# %%
import pandas as pd
from datetime import datetime

def add_columns_and_export(source_path, output_path):
  
    df = pd.read_csv(source_path, header=0)
    
    df['extract_time'] = datetime.now()
    
   
    df['source_name'] = source_path
  
    df.to_csv(output_path, index=False)


source_path = '/home/malak/bikestore_dim/staff/staffs.csv'
output_path = '/home/malak/landing/staff/staff.csv'
add_columns_and_export(source_path, output_path)

# %%
add_columns_and_export('/home/malak/bikestore_dim/customers/customers.csv', '/home/malak/landing/customers/customers.csv')

# %%
add_columns_and_export('/home/malak/bikestore_dim/products/products.csv', '/home/malak/landing/products/products.csv')

# %%
add_columns_and_export('/home/malak/bikestore_dim/stores/stores.csv', '/home/malak/landing/stores/stores.csv')

# %%
add_columns_and_export('/home/malak/bikestore_dim/brands/brands.csv', '/home/malak/landing/brands/brands.csv')

# %%
add_columns_and_export('/home/malak/bikestore_dim/categories/categories.csv', '/home/malak/landing/categories/categories.csv')

# %%
add_columns_and_export('/home/malak/bikestore_dim/stocks/stocks.csv', '/home/malak/landing/stocks/stocks.csv')
